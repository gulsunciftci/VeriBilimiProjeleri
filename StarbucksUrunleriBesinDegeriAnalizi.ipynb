# %% [markdown]
# DataSet= https://www.kaggle.com/datasets/utkarshx27/starbucks-nutrition

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %%
df=pd.read_csv("starbucks.csv",index_col=0) #veri kümesi içe aktarıldı

# %%
df.head() # head() metodu varsayılan olarak df’in ilk 5 satırını döndürür.
# Out:
#                           item  calories   fat  carb  fiber  protein    type
# 1                 8-Grain Roll       350   8.0    67      5       10  bakery
# 2            Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                Apple Fritter       420  20.0    59      0        5  bakery
# 4              Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5  Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery

# %%
df.tail(5) #tail() metodu varsayılan olarak son 5 satırı döndürür.
#Fakat biz burada tail() metoduna 7 parametresini göndererek son 7 satırı döndürmesini sağladık.
# Out:
#                                      item  calories   fat  carb  fiber  \
# 73        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 74                Turkey & Swiss Sandwich       390  13.0    36      2
# 75             Greek Yogurt Honey Parfait       300  12.0    44      0
# 76         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 73       32  sandwich
# 74       34  sandwich
# 75        8   parfait
# 76       10   parfait
# 77        7   parfait

# %%
df.info() #her bir sütunda null olmayan girdi sayısı ve sütunun veri tipi gibi bilgileri elde edebiliriz.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 1 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe() #sayısal verilere sahip olan sütunların max, min , std…gibi istatiksel değerlerini döndürür.
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df["item"].nunique() #Belirtilen eksene bağlı olarak her sütun veya satır için benzersiz değerlerin sayısını içeren bir Seri döndürür.
# Out:
# 77

# %%
df["item"].unique() ##Belirtilen eksene bağlı olarak her sütun veya satır için benzersiz değerlerin ismini içeren bir Seri döndürür.
# Out:
# array(['8-Grain Roll', 'Apple Bran Muffin', 'Apple Fritter',
#        'Banana Nut Loaf', 'Birthday Cake Mini Doughnut',
#        'Blueberry Oat Bar', 'Blueberry Scone',
#        'Bountiful Blueberry Muffin', 'Butter Croissant ', 'Cheese Danish',
#        'Chocolate Chunk Cookie', 'Chocolate Cinnamon Bread',
#        'Chocolate Croissant', 'Chocolate Old-Fashioned Doughnut',
#        'Chonga Bagel', 'Cinnamon Chip Scone', 'Cranberry Orange Scone',
#        'Double Chocolate Brownie', 'Double Fudge Mini Doughnut',
#        'Everything with Cheese Bagel', 'Ginger Molasses Cookie',
#        'Iced Lemon Pound Cake', 'Mallorca Sweet Bread',
#        'Maple Oat Pecan Scone ', 'Marble Pound Cake',
#        'Marshmallow Dream Bar', 'Morning Bun', 'Multigrain Bagel',
#        'Old-Fashioned Glazed Doughnut', 'Outrageous Oatmeal Cookie',
#        'Petite Vanilla Bean Scone', 'Plain Bagel', 'Pumpkin Bread',
#        'Pumpkin Scone ', 'Raspberry Scone', 'Raspberry Swirl Pound Cake',
# ...

# %%
df["type"].unique()
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
df.groupby("type")["item"].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
df.groupby("type")["item"].count().plot()
plt.title("Ürün Türleri")
plt.text(0,50,"Ürün Kategori Yelpazesi",bbox=dict(facecolor="yellow",alpha=0.5))
plt.show()

# %%
sns.countplot(x="type",data=df,palette="Set1") # countplot, Tek bir kategorik değişkenin dağılımını veya iki kategorik değişken arasındaki ilişkiyi bir çubuk grafiği oluşturarak gösterir. 
plt.title("Ürün Sayıları")
plt.show()

# %%
sns.catplot(kind="bar",x="type",y="calories",data=df)

# %%
sns.catplot(kind="bar",x="type",y="protein",data=df)
plt.title("Protein Değerleri")
plt.show()

# %%
sns.catplot(kind="bar",x="type",y="carb",data=df)
plt.title("Karbonhidrat Değerleri")
plt.show()

# %%
sns.catplot(kind="bar",x="type",y="fiber",data=df)
plt.title("Lif Değerleri")
plt.show()

# %%
df.corr() #korelasyon
# Out:
#           calories       fat      carb     fiber   protein
# calories  1.000000  0.758682  0.674999  0.260645  0.410398
# fat       0.758682  1.000000  0.144547 -0.028549  0.223470
# carb      0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber     0.260645 -0.028549  0.213044  1.000000  0.488564
# protein   0.410398  0.223470 -0.050789  0.488564  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.title("kalori ve yağ")
sns.scatterplot(x="calories",y="fat",data=df,s=30,edgecolor="red")
plt.plot()
# Out:
# []

# %%
sns.displot(x="calories",data=df,color="red",kde=True)
plt.title("kalori grafiği")
plt.show()

# %%
sns.displot(x="protein",data=df,color="green",kde=True)
plt.title("protein grafiği")
plt.show()

# %%
sns.displot(x="fat",data=df,color="purple",kde=True)
plt.title("yağ grafiği")
plt.show()

# %%
sns.displot(x="carb",data=df,color="violet",kde=True)
plt.title("karbonhidrat grafiği")
plt.show()

# %%
df.head()
# Out:
#                           item  calories   fat  carb  fiber  protein    type
# 1                 8-Grain Roll       350   8.0    67      5       10  bakery
# 2            Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                Apple Fritter       420  20.0    59      0        5  bakery
# 4              Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5  Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x=df[["calories","fat","carb","fiber","protein"]]
y=df["type"]

# %%
x
# Out:
#     calories   fat  carb  fiber  protein
# 1        350   8.0    67      5       10
# 2        350   9.0    64      7        6
# 3        420  20.0    59      0        5
# 4        490  19.0    75      4        7
# 5        130   6.0    17      0        0
# ..       ...   ...   ...    ...      ...
# 73       420  13.0    46      6       32
# 74       390  13.0    36      2       34
# 75       300  12.0    44      0        8
# 76       300   4.0    57      3       10
# 77       300   3.5    60      3        7
#
# [77 rows x 5 columns]

# %%
y
# Out:
# 1       bakery
# 2       bakery
# 3       bakery
# 4       bakery
# 5       bakery
#         ...
# 73    sandwich
# 74    sandwich
# 75     parfait
# 76     parfait
# 77     parfait
# Name: type, Length: 77, dtype: object

# %% [markdown]
# 1. train_test_split Nedir?
# İlk olarak, “train_test_split” fonksiyonunun ne olduğunu anlamak önemlidir. Bu fonksiyon, genellikle Python dilinde kullanılan bir kütüphane olan scikit-learn içinde bulunur. Temel amacı, veri setini rastgele bir şekilde iki alt küme olarak ayırmaktır: biri modelin eğitimi için kullanılacak eğitim seti (train set), diğeri ise modelin performansını değerlendirmek için kullanılacak test seti. Bu alt kümeler sayesinde, modelin gerçek dünya verilerine ne kadar iyi uyum sağlayabileceğini objektif bir şekilde ölçebiliriz.

# %%
x_train,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=DecisionTreeClassifier()
model.fit(x_train,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(xtest)

# %%
accuracy=accuracy_score(ytest,y_pred)

# %%
print("doğruluk",accuracy)
# Out:
# doğruluk 0.6875

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 1                            8-Grain Roll       350   8.0    67      5
# 2                       Apple Bran Muffin       350   9.0    64      7
# 3                           Apple Fritter       420  20.0    59      0
# 4                         Banana Nut Loaf       490  19.0    75      4
# 5             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 73        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 74                Turkey & Swiss Sandwich       390  13.0    36      2
# 75             Greek Yogurt Honey Parfait       300  12.0    44      0
# 76         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 1        10    bakery
# 2         6    bakery
# 3         5    bakery
# ...

# %%
prediction=model.predict([[550,3,60,1,5]])

# %%
print(prediction)
# Out:
# ['bakery']

# %%
from sklearn.tree import  plot_tree
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.style.use('dark_background')
mpl.rcParams['text.color'] = 'black'
plt.figure(figsize=(30,30))
plot_tree(model,feature_names=x.columns,class_names=model.classes_,filled=True)
plt.show()

# %%
df.carb.mean()
# Out:
# 44.87012987012987

# %%
df.carb-df.carb.mean()
# Out:
# 1     22.12987
# 2     19.12987
# 3     14.12987
# 4     30.12987
# 5    -27.87013
#         ...
# 73     1.12987
# 74    -8.87013
# 75    -0.87013
# 76    12.12987
# 77    15.12987
# Name: carb, Length: 77, dtype: float64

# %%
(df.carb-df.carb.mean()).pow(2).sum()
# Out:
# 20820.701298701297

# %%
filt=(df.carb<=40)

# %%
df1=df[filt] #40 dan az olanlar

# %%
df2=df[~filt] #40 dan az olanlar

# %%
df1
# Out:
#                                                  item  calories   fat  carb  \
# 5                         Birthday Cake Mini Doughnut       130   6.0    17
# 9                                   Butter Croissant        310  18.0    32
# 10                                      Cheese Danish       420  25.0    39
# 13                                Chocolate Croissant       300  17.0    34
# 19                         Double Fudge Mini Doughnut       130   7.0    16
# 31                          Petite Vanilla Bean Scone       140   5.0    21
# 42                                     Cheese & Fruit       480  28.0    39
# 43                                   Chicken & Hummus       270   8.0    29
# 44                              Chicken Lettuce Wraps       360  19.0    32
# 45                             Chipotle Chicken Wraps       380  15.0    35
# 46                                            Protein       380  19.0    37
# ...

# %%
df2
# Out:
#                                                  item  calories   fat  carb  \
# 1                                        8-Grain Roll       350   8.0    67
# 2                                   Apple Bran Muffin       350   9.0    64
# 3                                       Apple Fritter       420  20.0    59
# 4                                     Banana Nut Loaf       490  19.0    75
# 6                                   Blueberry Oat Bar       370  14.0    47
# 7                                     Blueberry Scone       460  22.0    61
# 8                          Bountiful Blueberry Muffin       370  14.0    55
# 11                             Chocolate Chunk Cookie       380  17.0    51
# 12                           Chocolate Cinnamon Bread       320  12.0    53
# 14                   Chocolate Old-Fashioned Doughnut       420  21.0    57
# 15                                       Chonga Bagel       310   5.0    52
# ...

# %%
df1.carb.mean()
# Out:
# 27.838709677419356

# %%
df2.carb.mean()
# Out:
# 56.34782608695652

# %% [markdown]
# # İlk Bölme :Error

# %%
(df1.carb-df1.carb.mean()).pow(2).sum()+(df2.carb-df2.carb.mean()).pow(2).sum()
# Out:
# 5768.628330995791

# %% [markdown]
# # İkinci Bölme

# %%
filt2=(df2.carb<=45)

# %%
df3=df2[filt2]

# %%
df4=df2[~filt2]

# %%
df3
# Out:
#                                                  item  calories   fat  carb  \
# 23                               Mallorca Sweet Bread       420  25.0    42
# 26                              Marshmallow Dream Bar       210   4.0    43
# 27                                        Morning Bun       350  16.0    45
# 62       Sausage & Cheddar Classic Breakfast Sandwich       500  28.0    41
# 65  Turkey Bacon & White Cheddar Classic Breakfast...       320   7.0    43
# 70                                 Ham & Swiss Panini       360   9.0    43
# 71                 Roasted Tomato & Mozzarella Panini       390  18.0    44
# 75                         Greek Yogurt Honey Parfait       300  12.0    44
#
#     fiber  protein           type
# 23      0        7         bakery
# 26      0        0         bakery
# 27      2        6         bakery
# 62      0       19  hot breakfast
# 65      3       18  hot breakfast
# 70      2       28       sandwich
# 71      3       15       sandwich
# ...

# %%
df4
# Out:
#                                              item  calories   fat  carb  \
# 1                                    8-Grain Roll       350   8.0    67
# 2                               Apple Bran Muffin       350   9.0    64
# 3                                   Apple Fritter       420  20.0    59
# 4                                 Banana Nut Loaf       490  19.0    75
# 6                               Blueberry Oat Bar       370  14.0    47
# 7                                 Blueberry Scone       460  22.0    61
# 8                      Bountiful Blueberry Muffin       370  14.0    55
# 11                         Chocolate Chunk Cookie       380  17.0    51
# 12                       Chocolate Cinnamon Bread       320  12.0    53
# 14               Chocolate Old-Fashioned Doughnut       420  21.0    57
# 15                                   Chonga Bagel       310   5.0    52
# 16                            Cinnamon Chip Scone       480  18.0    70
# ...

# %%
df4.carb.mean()
# Out:
# 59.13157894736842

# %%
(df1.carb-df1.carb.mean()).pow(2).sum()+(df3.carb-df3.carb.mean()).pow(2).sum()+(df4.carb-df4.carb.mean()).pow(2).sum()
# Out:
# 4075.4106536502545
